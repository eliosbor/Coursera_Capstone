# %%
#In this section I will use location data from the Phoenix area regarding where most restaurants are located, where restaurants receive the highest amount of business, and where restaurants make the most money.
